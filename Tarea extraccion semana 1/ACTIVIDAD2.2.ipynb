# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Convertir en dataframe
df= pd.read_csv("Copenhagen_Denmark.csv")
df
# Out:
#        Unnamed: 0                                               name  \
# 0               0  Beautiful, spacious, central, renovated Penthouse
# 1               1  155 m2 artist flat on Vesterbro, with 2 bathrooms
# 2               2                Cozy flat for Adults/Quiet for kids
# 3               3                     0 min. from everything in Cph.
# 4               4            Stylish apartment in central Copenhagen
# ...           ...                                                ...
# 21717       21717                          Cozy copenhagen apartment
# 21718       21718                                         Kopenhagen
# 21719       21719  Vesterbro - 2 Br - Cozy - Metro - Tivoli -4 Pe...
# 21720       21720  Østerbro - 1 Br - 3 People- Close To Metro (16...
# 21721       21721                    Charmerende lejlighed med altan
#
#       last_scraped                                        description  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21722 entries, 0 to 21721
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      21722 non-null  int64
#  1   name                            21722 non-null  object
#  2   last_scraped                    21722 non-null  object
#  3   description                     21118 non-null  object
#  4   neighborhood_overview           8396 non-null   object
#  5   host_id                         21722 non-null  int64
#  6   host_response_time              12328 non-null  object
#  7   host_response_rate              12328 non-null  object
#  8   host_acceptance_rate            16957 non-null  object
#  9   host_is_superhost               21512 non-null  object
#  10  host_listings_count             21717 non-null  float64
#  11  host_verifications              21717 non-null  object
# ...

# %%
filtro1=df["host_id"].head()
filtro1
# Out:
# 0    129976
# 1    140105
# 2    142143
# 3    122489
# 4    167511
# Name: host_id, dtype: int64

# %%
pd.options.display.max_columns=None

# %%
filtro2=df[df["first_review"]>= "2020-01-01"]

filtro2
# Out:
#        Unnamed: 0                                              name  \
# 6               6                      Gåafstand til hele København
# 98             98  Top location facing the Østre Anlæg park and SMK
# 112           112               Cozy “artist home” in Copenhagen V.
# 131           131                     City & Beachhouse Copbenhagen
# 134           134             Room with a nice view near Copenhagen
# ...           ...                                               ...
# 21521       21521                           Charming top floor flat
# 21523       21523                  Appartment -close to city center
# 21556       21556    Sjarmerende og skjermet idyll i Christianshavn
# 21557       21557                  Newly renovated apartment in CPH
# 21570       21570                   Cozy Amager Apt Metro & Parking
#
#       last_scraped                                        description  \
# 6       2025-03-24  Welcome to our home with a view of the Lakes. ...
# ...

# %%
#Analizar categorias de una columna
df6 = df.groupby(['host_response_time'])['host_response_time'].count()
df6
# Out:
# host_response_time
# a few days or more     859
# within a day          3517
# within a few hours    2980
# within an hour        4972
# Name: host_response_time, dtype: int64

# %%
##Los registros de los host que responden “a más tardar en 1 día” 
host_res = df[
    (df["host_response_time"] == "within a day") |  
(df["host_response_time"] == "within an hour") |
(df["host_response_time"] == "within a few hours")]
host_res
# Out:
#        Unnamed: 0                                               name  \
# 1               1  155 m2 artist flat on Vesterbro, with 2 bathrooms
# 3               3                     0 min. from everything in Cph.
# 4               4            Stylish apartment in central Copenhagen
# 5               5                   10 min. from city centre on bike
# 6               6                       Gåafstand til hele København
# ...           ...                                                ...
# 21716       21716                          Lejlighed i bedste område
# 21717       21717                          Cozy copenhagen apartment
# 21719       21719  Vesterbro - 2 Br - Cozy - Metro - Tivoli -4 Pe...
# 21720       21720  Østerbro - 1 Br - 3 People- Close To Metro (16...
# 21721       21721                    Charmerende lejlighed med altan
#
#       last_scraped                                        description  \
# ...

# %%
##Los registros de las filas “Múltiplos de 200… (400, 600, 800, etc.)” 

multiplos_200= df.iloc[0::200,:]
multiplos_200
# Out:
#        Unnamed: 0                                               name  \
# 0               0  Beautiful, spacious, central, renovated Penthouse
# 200           200                Apt. on Christianshavn w. balconies
# 400           400                       Central Copenhagen apartment
# 600           600                106 m2 designer home, kids friendly
# 800           800                  Sweet Apartment  in Copenhagen Dk
# ...           ...                                                ...
# 20800       20800                       Central two-person apartment
# 21000       21000     Unique Manor Apartment With Waterfront Balcony
# 21200       21200            Nice  and quiet area close to the marsh
# 21400       21400                          Colorful family apartment
# 21600       21600                   Quiet & Cozy Studio - Copenhagen
#
#       last_scraped                                        description  \
# ...

# %%
##Los registros de los tipos de cuarto: “Entire home”  y “Private room”
cuartos = df[
    (df["room_type"] == "Entire home/apt") |
(df["room_type"] == "Private room")]
cuartos
# Out:
#        Unnamed: 0                                               name  \
# 0               0  Beautiful, spacious, central, renovated Penthouse
# 1               1  155 m2 artist flat on Vesterbro, with 2 bathrooms
# 2               2                Cozy flat for Adults/Quiet for kids
# 3               3                     0 min. from everything in Cph.
# 4               4            Stylish apartment in central Copenhagen
# ...           ...                                                ...
# 21717       21717                          Cozy copenhagen apartment
# 21718       21718                                         Kopenhagen
# 21719       21719  Vesterbro - 2 Br - Cozy - Metro - Tivoli -4 Pe...
# 21720       21720  Østerbro - 1 Br - 3 People- Close To Metro (16...
# 21721       21721                    Charmerende lejlighed med altan
#
#       last_scraped                                        description  \
# ...

# %%
#Analizar categorias de una columna
df9 = df.groupby(['room_type'])['room_type'].count()
df9
# Out:
# room_type
# Entire home/apt    19829
# Hotel room             4
# Private room        1878
# Shared room           11
# Name: room_type, dtype: int64

# %%
##Los registros que “a lo mucho cuenten con 4 camas” 
ndecamas=df[df["beds"] <= 4]
ndecamas
# Out:
#        Unnamed: 0                                               name  \
# 3               3                     0 min. from everything in Cph.
# 4               4            Stylish apartment in central Copenhagen
# 5               5                   10 min. from city centre on bike
# 7               7                Clean room in peacefull part of Cph
# 9               9  Apartment in the heart of Copenhagen with lake...
# ...           ...                                                ...
# 21717       21717                          Cozy copenhagen apartment
# 21718       21718                                         Kopenhagen
# 21719       21719  Vesterbro - 2 Br - Cozy - Metro - Tivoli -4 Pe...
# 21720       21720  Østerbro - 1 Br - 3 People- Close To Metro (16...
# 21721       21721                    Charmerende lejlighed med altan
#
#       last_scraped                                        description  \
# ...

# %%
#Los registros que “sean superhost”
host = df[df["host_is_superhost"] == "t"]
host
# Out:
#        Unnamed: 0                                               name  \
# 1               1  155 m2 artist flat on Vesterbro, with 2 bathrooms
# 3               3                     0 min. from everything in Cph.
# 4               4            Stylish apartment in central Copenhagen
# 5               5                   10 min. from city centre on bike
# 6               6                       Gåafstand til hele København
# ...           ...                                                ...
# 21568       21568            205m2  / Manor Apartment  / City Center
# 21639       21639                      Luksusbolig ved Grøbrødretorv
# 21642       21642                   Lille lejlighed i hjertet af KBH
# 21643       21643                    Smuk lejlighed i Centrum af KBH
# 21688       21688                        Spacious & Unique Cph House
#
#       last_scraped                                        description  \
# ...

# %%
##h) Los registros de las columnas “impares”

columnas= df.iloc[:, 1::2] #Columnas con incrementos de 2 a partir de la columna 1

columnas
# Out:
#                                                     name  \
# 0      Beautiful, spacious, central, renovated Penthouse
# 1      155 m2 artist flat on Vesterbro, with 2 bathrooms
# 2                    Cozy flat for Adults/Quiet for kids
# 3                         0 min. from everything in Cph.
# 4                Stylish apartment in central Copenhagen
# ...                                                  ...
# 21717                          Cozy copenhagen apartment
# 21718                                         Kopenhagen
# 21719  Vesterbro - 2 Br - Cozy - Metro - Tivoli -4 Pe...
# 21720  Østerbro - 1 Br - 3 People- Close To Metro (16...
# 21721                    Charmerende lejlighed med altan
#
#                                              description    host_id  \
# 0      Welcome to our home, we hope you will enjoy Wo...     129976
# 1      You enter a narrow entrance and feel the good ...     140105
# 2      Our flat is placed in a Central AND Quiet neig...     142143
# ...
